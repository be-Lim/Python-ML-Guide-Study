# %% [markdown]
# # **이변수 함수 최적화**

# %%
from hyperopt import hp
#입력 변수명과 입력값 검색 공간 설정
search_space = {'x': hp.quniform('x',-10,10,1), 'y': hp.quniform('y',-15,15,1)}

# %%
from hyperopt import STATUS_OK
#목적함수 생성
def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y

    return retval

# %%
from hyperopt import fmin, tpe, Trials
import numpy as np
#입력 결과값을 저장한 객체값 생성
trial_val = Trials()
#목적함수의 최소값을 반환하는 최적 입력 변수값을 5번의 시도로 찾음
best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5, trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 546.55trial/s, best loss: -224.0]
# best: {'x': np.float64(-4.0), 'y': np.float64(12.0)}

# %%
trial_val = Trials()
#목적함수의 최소값을 반환하는 최적 입력 변수값을 20번의 시도로 찾음
best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20, trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_02)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 743.62trial/s, best loss: -296.0]
# best: {'x': np.float64(2.0), 'y': np.float64(15.0)}

# %%
print(trial_val.results)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]

# %%
len(trial_val.results)
# Out:
# 20

# %%
print(trial_val.vals)
# Out:
# {'x': [np.float64(-6.0), np.float64(-4.0), np.float64(4.0), np.float64(-4.0), np.float64(9.0), np.float64(2.0), np.float64(10.0), np.float64(-9.0), np.float64(-8.0), np.float64(-0.0), np.float64(-0.0), np.float64(1.0), np.float64(9.0), np.float64(6.0), np.float64(9.0), np.float64(2.0), np.float64(-2.0), np.float64(-4.0), np.float64(7.0), np.float64(-0.0)], 'y': [np.float64(5.0), np.float64(10.0), np.float64(-2.0), np.float64(12.0), np.float64(1.0), np.float64(15.0), np.float64(7.0), np.float64(-10.0), np.float64(0.0), np.float64(-5.0), np.float64(-3.0), np.float64(2.0), np.float64(4.0), np.float64(10.0), np.float64(3.0), np.float64(3.0), np.float64(-14.0), np.float64(-8.0), np.float64(11.0), np.float64(-0.0)]}

# %%
import pandas as pd
losses = [loss_dict['loss'] for loss_dict in trial_val.results]
result_dict = trial_val.vals | {'losses': losses}
result_df = pd.DataFrame(result_dict)
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %% [markdown]
# # **XGBoost 하이퍼 파라미터 최적화**

# %%
#필요한 라이브러리 임포트 및 데이터 로딩
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

dataset = load_breast_cancer()
cancer_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df['target'] = dataset.target
X_features = cancer_df.iloc[:,:-1]
y_label = cancer_df.iloc[:,-1]

#전체 데이터 중 80%는 학습용, 20%는 테스트용 데이터로 추출
X_train, X_test, y_train, y_test = train_test_split(X_features, y_label, test_size=0.2, random_state=156)
#학습용 데이터 중 90%는 학습용, 10%는 검증용 데이터로 추출
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.1, random_state=156)

# %%
#하이퍼 파라미터 검색 공간 설정
from hyperopt import hp
xgb_search_space = {'max_depth': hp.quniform('max_depth',5,20,1),
                    'min_child_weight': hp.quniform('min_child_weight',1,2,1),
                    'learning_rate': hp.uniform('learning_rate',0.01,0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree',0.5,1)}

# %%
#목적 함수 설정
from hyperopt import STATUS_OK
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier

def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100,
                            max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)

    return {'loss':-1 * np.mean(accuracy), 'status':STATUS_OK}

# %%
#최적 하이퍼 파라미터 도출
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50,
            trials=trial_val,
            rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
# 100%|██████████| 50/50 [00:26<00:00,  1.89trial/s, best loss: -0.9670616939700244]
# best: {'colsample_bytree': np.float64(0.858999866296754), 'learning_rate': np.float64(0.17459146963933464), 'max_depth': np.float64(20.0), 'min_child_weight': np.float64(2.0)}

# %%
print(f'colsample_bytree: {best['colsample_bytree']:.5f}, learning_rate: {best['learning_rate']:.5f}, max_depth: {int(best['max_depth'])}, min_child_weight: {int(best['min_child_weight'])}')
# Out:
# colsample_bytree: 0.85900, learning_rate: 0.17459, max_depth: 20, min_child_weight: 2

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, f1_score, confusion_matrix

def get_clf_eval(y_test, pred, pred_proba):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    print(f'정확도: {accuracy:.4f}, 정밀도: {precision:.4f}, 재현율: {recall:.4f}, F1: {f1:.4f}, AUC: {roc_auc:.4f}')

# %%
#도출한 최적 하이퍼 파라미터들을 XGBClassifier에 입력하여 성능 평가
xgb_wrapper = XGBClassifier(n_estimators=400,
                            learning_rate=round(best['learning_rate'], 5),
                            max_depth=int(best['max_depth']),
                            min_child_weight=int(best['min_child_weight']),
                            colsample_bytree=round(best['colsample_bytree'], 5),
                            early_stopping_rounds=50,
                            eval_metric='logloss')
evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:,1]

get_clf_eval(y_test, preds, pred_proba)
# Out:
# [0]	validation_0-logloss:0.53178	validation_1-logloss:0.57774
# [1]	validation_0-logloss:0.43693	validation_1-logloss:0.53104
# [2]	validation_0-logloss:0.36375	validation_1-logloss:0.46939
# [3]	validation_0-logloss:0.30808	validation_1-logloss:0.42846
# [4]	validation_0-logloss:0.26254	validation_1-logloss:0.39423
# [5]	validation_0-logloss:0.22780	validation_1-logloss:0.36739
# [6]	validation_0-logloss:0.19887	validation_1-logloss:0.35126
# [7]	validation_0-logloss:0.17442	validation_1-logloss:0.33290
# [8]	validation_0-logloss:0.15590	validation_1-logloss:0.31895
# [9]	validation_0-logloss:0.13757	validation_1-logloss:0.30455
# [10]	validation_0-logloss:0.12339	validation_1-logloss:0.29727
# [11]	validation_0-logloss:0.11020	validation_1-logloss:0.28950
# [12]	validation_0-logloss:0.09900	validation_1-logloss:0.28643
# [13]	validation_0-logloss:0.09022	validation_1-logloss:0.28405
# [14]	validation_0-logloss:0.08217	validation_1-logloss:0.27688
# [15]	validation_0-logloss:0.07616	validation_1-logloss:0.27643
# [16]	validation_0-logloss:0.07095	validation_1-logloss:0.27355
# [17]	validation_0-logloss:0.06629	validation_1-logloss:0.27364
# [18]	validation_0-logloss:0.06119	validation_1-logloss:0.27173
# [19]	validation_0-logloss:0.05631	validation_1-logloss:0.26365
# [20]	validation_0-logloss:0.05239	validation_1-logloss:0.26572
# [21]	validation_0-logloss:0.04879	validation_1-logloss:0.26709
# [22]	validation_0-logloss:0.04548	validation_1-logloss:0.26840
# [23]	validation_0-logloss:0.04338	validation_1-logloss:0.26771
# [24]	validation_0-logloss:0.04141	validation_1-logloss:0.26593
# [25]	validation_0-logloss:0.03881	validation_1-logloss:0.26665
# [26]	validation_0-logloss:0.03709	validation_1-logloss:0.26982
# [27]	validation_0-logloss:0.03529	validation_1-logloss:0.26741
# [28]	validation_0-logloss:0.03365	validation_1-logloss:0.26561
# [29]	validation_0-logloss:0.03227	validation_1-logloss:0.26626
# [30]	validation_0-logloss:0.03126	validation_1-logloss:0.26297
# [31]	validation_0-logloss:0.02974	validation_1-logloss:0.26561
# [32]	validation_0-logloss:0.02882	validation_1-logloss:0.26095
# [33]	validation_0-logloss:0.02798	validation_1-logloss:0.26256
# [34]	validation_0-logloss:0.02732	validation_1-logloss:0.25907
# [35]	validation_0-logloss:0.02673	validation_1-logloss:0.25717
# [36]	validation_0-logloss:0.02598	validation_1-logloss:0.25705
# [37]	validation_0-logloss:0.02536	validation_1-logloss:0.25702
# [38]	validation_0-logloss:0.02485	validation_1-logloss:0.25527
# [39]	validation_0-logloss:0.02455	validation_1-logloss:0.25485
# [40]	validation_0-logloss:0.02412	validation_1-logloss:0.24979
# [41]	validation_0-logloss:0.02350	validation_1-logloss:0.24615
# [42]	validation_0-logloss:0.02302	validation_1-logloss:0.24808
# [43]	validation_0-logloss:0.02248	validation_1-logloss:0.24998
# [44]	validation_0-logloss:0.02225	validation_1-logloss:0.25217
# [45]	validation_0-logloss:0.02203	validation_1-logloss:0.25041
# [46]	validation_0-logloss:0.02163	validation_1-logloss:0.24894
# [47]	validation_0-logloss:0.02145	validation_1-logloss:0.24993
# [48]	validation_0-logloss:0.02129	validation_1-logloss:0.24965
# [49]	validation_0-logloss:0.02092	validation_1-logloss:0.25144
# [50]	validation_0-logloss:0.02076	validation_1-logloss:0.25368
# [51]	validation_0-logloss:0.02062	validation_1-logloss:0.25084
# [52]	validation_0-logloss:0.02043	validation_1-logloss:0.25295
# [53]	validation_0-logloss:0.02029	validation_1-logloss:0.25485
# [54]	validation_0-logloss:0.02011	validation_1-logloss:0.25320
# [55]	validation_0-logloss:0.01997	validation_1-logloss:0.25422
# [56]	validation_0-logloss:0.01983	validation_1-logloss:0.25283
# [57]	validation_0-logloss:0.01969	validation_1-logloss:0.25474
# [58]	validation_0-logloss:0.01955	validation_1-logloss:0.25453
# [59]	validation_0-logloss:0.01943	validation_1-logloss:0.25187
# [60]	validation_0-logloss:0.01931	validation_1-logloss:0.25056
# [61]	validation_0-logloss:0.01918	validation_1-logloss:0.25244
# [62]	validation_0-logloss:0.01906	validation_1-logloss:0.25239
# [63]	validation_0-logloss:0.01894	validation_1-logloss:0.25416
# [64]	validation_0-logloss:0.01883	validation_1-logloss:0.25288
# [65]	validation_0-logloss:0.01872	validation_1-logloss:0.25354
# [66]	validation_0-logloss:0.01861	validation_1-logloss:0.25336
# [67]	validation_0-logloss:0.01850	validation_1-logloss:0.25076
# [68]	validation_0-logloss:0.01840	validation_1-logloss:0.25195
# [69]	validation_0-logloss:0.01829	validation_1-logloss:0.24946
# [70]	validation_0-logloss:0.01819	validation_1-logloss:0.25122
# [71]	validation_0-logloss:0.01809	validation_1-logloss:0.24999
# [72]	validation_0-logloss:0.01799	validation_1-logloss:0.24994
# [73]	validation_0-logloss:0.01790	validation_1-logloss:0.25166
# [74]	validation_0-logloss:0.01780	validation_1-logloss:0.24915
# [75]	validation_0-logloss:0.01771	validation_1-logloss:0.25026
# [76]	validation_0-logloss:0.01762	validation_1-logloss:0.24932
# [77]	validation_0-logloss:0.01753	validation_1-logloss:0.24701
# [78]	validation_0-logloss:0.01744	validation_1-logloss:0.24812
# [79]	validation_0-logloss:0.01736	validation_1-logloss:0.24808
# [80]	validation_0-logloss:0.01728	validation_1-logloss:0.24700
# [81]	validation_0-logloss:0.01720	validation_1-logloss:0.24706
# [82]	validation_0-logloss:0.01712	validation_1-logloss:0.24477
# [83]	validation_0-logloss:0.01704	validation_1-logloss:0.24458
# [84]	validation_0-logloss:0.01696	validation_1-logloss:0.24640
# [85]	validation_0-logloss:0.01689	validation_1-logloss:0.24554
# [86]	validation_0-logloss:0.01681	validation_1-logloss:0.24563
# [87]	validation_0-logloss:0.01673	validation_1-logloss:0.24469
# [88]	validation_0-logloss:0.01666	validation_1-logloss:0.24570
# [89]	validation_0-logloss:0.01659	validation_1-logloss:0.24355
# [90]	validation_0-logloss:0.01652	validation_1-logloss:0.24367
# [91]	validation_0-logloss:0.01645	validation_1-logloss:0.24350
# [92]	validation_0-logloss:0.01638	validation_1-logloss:0.24267
# [93]	validation_0-logloss:0.01632	validation_1-logloss:0.24436
# [94]	validation_0-logloss:0.01625	validation_1-logloss:0.24429
# [95]	validation_0-logloss:0.01619	validation_1-logloss:0.24224
# [96]	validation_0-logloss:0.01612	validation_1-logloss:0.24237
# [97]	validation_0-logloss:0.01605	validation_1-logloss:0.24329
# [98]	validation_0-logloss:0.01599	validation_1-logloss:0.24232
# [99]	validation_0-logloss:0.01593	validation_1-logloss:0.24043
# [100]	validation_0-logloss:0.01587	validation_1-logloss:0.24061
# [101]	validation_0-logloss:0.01581	validation_1-logloss:0.24042
# [102]	validation_0-logloss:0.01575	validation_1-logloss:0.24207
# [103]	validation_0-logloss:0.01569	validation_1-logloss:0.24188
# [104]	validation_0-logloss:0.01563	validation_1-logloss:0.24279
# [105]	validation_0-logloss:0.01557	validation_1-logloss:0.24094
# [106]	validation_0-logloss:0.01551	validation_1-logloss:0.24085
# [107]	validation_0-logloss:0.01546	validation_1-logloss:0.24104
# [108]	validation_0-logloss:0.01540	validation_1-logloss:0.24029
# [109]	validation_0-logloss:0.01535	validation_1-logloss:0.24118
# [110]	validation_0-logloss:0.01529	validation_1-logloss:0.24033
# [111]	validation_0-logloss:0.01524	validation_1-logloss:0.24025
# [112]	validation_0-logloss:0.01519	validation_1-logloss:0.24112
# [113]	validation_0-logloss:0.01514	validation_1-logloss:0.23940
# [114]	validation_0-logloss:0.01509	validation_1-logloss:0.23962
# [115]	validation_0-logloss:0.01503	validation_1-logloss:0.24118
# [116]	validation_0-logloss:0.01498	validation_1-logloss:0.24037
# [117]	validation_0-logloss:0.01493	validation_1-logloss:0.24015
# [118]	validation_0-logloss:0.01489	validation_1-logloss:0.23936
# [119]	validation_0-logloss:0.01484	validation_1-logloss:0.23958
# [120]	validation_0-logloss:0.01479	validation_1-logloss:0.23794
# [121]	validation_0-logloss:0.01474	validation_1-logloss:0.23883
# [122]	validation_0-logloss:0.01470	validation_1-logloss:0.24029
# [123]	validation_0-logloss:0.01465	validation_1-logloss:0.24007
# [124]	validation_0-logloss:0.01461	validation_1-logloss:0.23982
# [125]	validation_0-logloss:0.01457	validation_1-logloss:0.23909
# [126]	validation_0-logloss:0.01452	validation_1-logloss:0.23932
# [127]	validation_0-logloss:0.01448	validation_1-logloss:0.23777
# [128]	validation_0-logloss:0.01443	validation_1-logloss:0.23868
# [129]	validation_0-logloss:0.01439	validation_1-logloss:0.23894
# [130]	validation_0-logloss:0.01435	validation_1-logloss:0.23745
# [131]	validation_0-logloss:0.01431	validation_1-logloss:0.23724
# [132]	validation_0-logloss:0.01427	validation_1-logloss:0.23868
# [133]	validation_0-logloss:0.01423	validation_1-logloss:0.23802
# [134]	validation_0-logloss:0.01419	validation_1-logloss:0.23830
# [135]	validation_0-logloss:0.01415	validation_1-logloss:0.23780
# [136]	validation_0-logloss:0.01412	validation_1-logloss:0.23759
# [137]	validation_0-logloss:0.01408	validation_1-logloss:0.23787
# [138]	validation_0-logloss:0.01404	validation_1-logloss:0.23715
# [139]	validation_0-logloss:0.01401	validation_1-logloss:0.23852
# [140]	validation_0-logloss:0.01397	validation_1-logloss:0.23935
# [141]	validation_0-logloss:0.01393	validation_1-logloss:0.23869
# [142]	validation_0-logloss:0.01390	validation_1-logloss:0.23848
# [143]	validation_0-logloss:0.01386	validation_1-logloss:0.23801
# [144]	validation_0-logloss:0.01383	validation_1-logloss:0.23742
# [145]	validation_0-logloss:0.01380	validation_1-logloss:0.23772
# [146]	validation_0-logloss:0.01376	validation_1-logloss:0.23752
# [147]	validation_0-logloss:0.01373	validation_1-logloss:0.23838
# [148]	validation_0-logloss:0.01370	validation_1-logloss:0.23771
# [149]	validation_0-logloss:0.01367	validation_1-logloss:0.23800
# [150]	validation_0-logloss:0.01364	validation_1-logloss:0.23782
# [151]	validation_0-logloss:0.01361	validation_1-logloss:0.23722
# [152]	validation_0-logloss:0.01358	validation_1-logloss:0.23854
# [153]	validation_0-logloss:0.01355	validation_1-logloss:0.23933
# [154]	validation_0-logloss:0.01352	validation_1-logloss:0.23891
# [155]	validation_0-logloss:0.01349	validation_1-logloss:0.23836
# [156]	validation_0-logloss:0.01346	validation_1-logloss:0.23867
# [157]	validation_0-logloss:0.01343	validation_1-logloss:0.23837
# [158]	validation_0-logloss:0.01341	validation_1-logloss:0.23800
# [159]	validation_0-logloss:0.01338	validation_1-logloss:0.23921
# [160]	validation_0-logloss:0.01336	validation_1-logloss:0.23899
# [161]	validation_0-logloss:0.01333	validation_1-logloss:0.23929
# [162]	validation_0-logloss:0.01330	validation_1-logloss:0.23877
# [163]	validation_0-logloss:0.01328	validation_1-logloss:0.23842
# [164]	validation_0-logloss:0.01326	validation_1-logloss:0.23820
# [165]	validation_0-logloss:0.01323	validation_1-logloss:0.23794
# [166]	validation_0-logloss:0.01321	validation_1-logloss:0.23871
# [167]	validation_0-logloss:0.01319	validation_1-logloss:0.23823
# [168]	validation_0-logloss:0.01316	validation_1-logloss:0.23853
# [169]	validation_0-logloss:0.01314	validation_1-logloss:0.23967
# [170]	validation_0-logloss:0.01312	validation_1-logloss:0.23946
# [171]	validation_0-logloss:0.01309	validation_1-logloss:0.23913
# [172]	validation_0-logloss:0.01307	validation_1-logloss:0.23906
# [173]	validation_0-logloss:0.01305	validation_1-logloss:0.23850
# [174]	validation_0-logloss:0.01303	validation_1-logloss:0.23923
# [175]	validation_0-logloss:0.01301	validation_1-logloss:0.23880
# [176]	validation_0-logloss:0.01299	validation_1-logloss:0.23908
# [177]	validation_0-logloss:0.01297	validation_1-logloss:0.23888
# [178]	validation_0-logloss:0.01295	validation_1-logloss:0.23857
# [179]	validation_0-logloss:0.01293	validation_1-logloss:0.23831
# [180]	validation_0-logloss:0.01291	validation_1-logloss:0.23901
# [181]	validation_0-logloss:0.01289	validation_1-logloss:0.23860
# [182]	validation_0-logloss:0.01288	validation_1-logloss:0.23840
# [183]	validation_0-logloss:0.01286	validation_1-logloss:0.23907
# [184]	validation_0-logloss:0.01284	validation_1-logloss:0.23882
# [185]	validation_0-logloss:0.01283	validation_1-logloss:0.23856
# [186]	validation_0-logloss:0.01281	validation_1-logloss:0.23818
# [187]	validation_0-logloss:0.01279	validation_1-logloss:0.23799
# [188]	validation_0-logloss:0.01278	validation_1-logloss:0.23865
# 오차 행렬
# [[35  2]
#  [ 3 74]]
# 정확도: 0.9561, 정밀도: 0.9737, 재현율: 0.9610, F1: 0.9673, AUC: 0.9944
